# %% [markdown]
# # Assignment - Machine Learning Basic Linear Regression with Python
# ### Important Link: https://towardsdatascience.com/machine-learning-simple-linear-regression-with-python-f04ecfdadc13
# ## **Two basic steps of Machine Learning:**
# ### 1. Training
# ### 2. Predict
# ### **Libraries:**
# ### We will use 4 libraries such as numpy and pandas to work with data set, sklearn to implement machine learning functions, and matplotlib to visualize our plots for viewing

# %%
# Improting Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('mldata.csv')
dataset= dataset[["age", "weight"]]
X = dataset.iloc[:, :-1].values #get a copy of dataset 1st column i.e. age
y = dataset.iloc[:, 1].values #get array of dataset in column 2nd i.e weight

# %% [markdown]
# ### Choosing two third data to train and one third data to test (test_size=1/3)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Code Explanation:**
# ### - regressor = LinearRegression(): our training model which will implement the Linear Regression.
# ### - regressor.fit: in this line, we pass the X_train which contains value of Year Experience and y_train which contains values of particular Salary to form up the model. This is the training process.

# %% [markdown]
# ### Visualizing our training model and testing model

# %%
viz_train = plt
viz_train.scatter(X_train, y_train, color='red')
viz_train.plot(X_train, regressor.predict(X_train), color='blue')
viz_train.title('Age VS Weight (Training set)')
viz_train.xlabel('Age')
viz_train.ylabel('Weight')
viz_train.show()

# Visualizing the Test set results
viz_test = plt
viz_test.scatter(X_test, y_test, color='red')
viz_test.plot(X_train, regressor.predict(X_train), color='blue')
viz_test.title('Age VS Weight (Test set)')
viz_test.xlabel('Age')
viz_test.ylabel('Weight')
viz_test.show()

# %% [markdown]
# ### calculate (predict) any values of X:Age depends on y:Weight or any values of y depends on X

# %%
y_pred = regressor.predict([[35]])
y_pred
# Out:
# array([76.4352169])
